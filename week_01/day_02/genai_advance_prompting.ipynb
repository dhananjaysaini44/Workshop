# %% [markdown]
# # Advance prompting using seprate prompt files in the ROOT

# %%
# %pip install python-dotenv
# %pip install google-genai
# %pip install pydantic
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-dotenv in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (1.1.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-genai in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (1.61.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from google-genai) (4.10.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai) (2.48.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from google-genai) (2.11.7)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from google-genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.20)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (45.0.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (4.9.1)
# Requirement already satisfied: certifi in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (0.6.2)
# Requirement already satisfied: cffi>=1.14 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from cffi>=1.14->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (2.23)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydantic in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (2.11.7)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from pydantic) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from pydantic) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in C:\Users\DHANANJAY\AppData\Roaming\Python\Python313\site-packages (from pydantic) (0.4.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
import os
import sys
from google import genai
from google.genai import types
from pydantic import BaseModel
import json
from pathlib import Path

# %%
load_dotenv()

api_key_gemini = os.getenv("GEMINI_API_KEY")
print(api_key_gemini[:10])
# Out:
# AQ.Ab8RN6K

# %% [markdown]
# ### Gemini API gateway

# %%
client = genai.Client(api_key = api_key_gemini)

response = client.models.generate_content(
    model = "gemini-3.6-flash",
    contents = "Hello"
)

print(response.text)

# %% [markdown]
# ### Create system prompt files
#
# In the directory ../prompts create files - <br>
# 1. common.py
# 2. learning.py
# 3. interview.py
# 4. resume.py
# 5. rag.py
# 6. etc.

# %% [markdown]
# ### Import System prompts and start using

# %%
ROOT = os.path.abspath("../..")

if ROOT not in sys.path:
    sys.path.append(ROOT)

# %%
from prompts.learning import (
    LEARNING_SYSTEM_PROMPT,
    LEARNING_TEMPLATE
)

# %%
print(LEARNING_TEMPLATE)
# Out:
# TASK:
# {task}
#
# CONTEXT:
# I am a final-year Computer Science student with:
# - Python knowledge
# - Basic Machine Learning knowledge
# - Interest in AI Engineering
#
# CONSTRAINTS:
# - No unnecessary jargon
# - Explain intuitively first
# - Add examples
# - Mention production use cases
#
# OUTPUT FORMAT:
#
# 1. Concept
# 2. Why It Matters
# 3. Example
# 4. Common Mistakes
# 5. Interview Questions

# %%
prompt = LEARNING_TEMPLATE.format(
    task = "Explain embeddings and vector database"
)

print(prompt)
# Out:
# TASK:
# Explain embeddings and vector database
#
# CONTEXT:
# I am a final-year Computer Science student with:
# - Python knowledge
# - Basic Machine Learning knowledge
# - Interest in AI Engineering
#
# CONSTRAINTS:
# - No unnecessary jargon
# - Explain intuitively first
# - Add examples
# - Mention production use cases
#
# OUTPUT FORMAT:
#
# 1. Concept
# 2. Why It Matters
# 3. Example
# 4. Common Mistakes
# 5. Interview Questions

# %%
response = client.models.generate_content(
    model = "gemini-3.6-flash", 
    contents = prompt,
    config = types.GenerateContentConfig(
        systemInstruction = LEARNING_SYSTEM_PROMPT,
        temperature = 0.2
    )
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 response = client.models.generate_content(
#       2     model = "gemini-3.6-flash",
#       3     contents = prompt,
#       4     config = types.GenerateContentConfig(
#       5         systemInstruction = LEARNING_SYSTEM_PROMPT,
#       6         temperature = 0.2
#       7     )
#       8 )
#      10 print(response.text)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\models.py:5227, in Models.generate_content(self, model, contents, config)
#    5225 while remaining_remote_calls_afc > 0:
#    5226   i += 1
# -> 5227   response = self._generate_content(
#    5228       model=model, contents=contents, config=parsed_config
#    5229   )
#    5231   function_map = _extra_utils.get_function_map(parsed_config)
#    5232   if not function_map:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\models.py:4009, in Models._generate_content(self, model, contents, config)
#    4006 request_dict = _common.convert_to_dict(request_dict)
#    4007 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4009 response = self._api_client.request(
#    4010     'post', path, request_dict, http_options
#    4011 )
#    4013 if config is not None and getattr(
#    4014     config, 'should_return_http_response', None
#    4015 ):
#    4016   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\_api_client.py:1386, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1376 def request(
#    1377     self,
#    1378     http_method: str,
#    (...)   1381     http_options: Optional[HttpOptionsOrDict] = None,
#    1382 ) -> SdkHttpResponse:
#    1383   http_request = self._build_request(
#    1384       http_method, path, request_dict, http_options
#    1385   )
# -> 1386   response = self._request(http_request, http_options, stream=False)
#    1387   response_body = (
#    1388       response.response_stream[0] if response.response_stream else ''
#    1389   )
#    1390   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\_api_client.py:1222, in BaseApiClient._request(self, http_request, http_options, stream)
#    1219     retry = tenacity.Retrying(**retry_kwargs)
#    1220     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1222 return self._retry(self._request_once, http_request, stream)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File C:\Program Files\Python313\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File C:\Program Files\Python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\_api_client.py:1199, in BaseApiClient._request_once(self, http_request, stream)
#    1191 else:
#    1192   response = self._httpx_client.request(
#    1193       method=http_request.method,
#    1194       url=http_request.url,
#    (...)   1197       timeout=http_request.timeout,
#    1198   )
# -> 1199   errors.APIError.raise_for_response(response)
#    1200   return HttpResponse(
#    1201       response.headers, response if stream else [response.text]
#    1202   )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\errors.py:121, in APIError.raise_for_response(cls, response)
#     118 else:
#     119   response_json = response.body_segments[0].get('error', {})
# --> 121 cls.raise_error(response.status_code, response_json, response)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\genai\errors.py:148, in APIError.raise_error(cls, status_code, response_json, response)
#     146   raise ClientError(status_code, response_json, response)
#     147 elif 500 <= status_code < 600:
# --> 148   raise ServerError(status_code, response_json, response)
#     149 else:
#     150   raise cls(status_code, response_json, response)
#
# ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}

# %%
class ResumeAnalysis(BaseModel):
    skills: list[str]
    strengths: list[str]

# %%
print(os.getcwd())
# Out:
# C:\Users\DHANANJAY\Coding_Creations\Workshop\week_01\day_02

# %%
ROOT = Path.cwd().parents[1]

print(ROOT)

DATA_DIR = ROOT / "data"

print(DATA_DIR)
# Out:
# C:\Users\DHANANJAY\Coding_Creations\Workshop
# C:\Users\DHANANJAY\Coding_Creations\Workshop\data

# %%
with open(DATA_DIR / "notes.txt", "a") as file:
    file.write("\nHello World")
    
with open(DATA_DIR / "notes.txt", "r") as file:
    content = file.read()
    
print(content)
# Out:
# Hello World
# Hello World
# Hello World
