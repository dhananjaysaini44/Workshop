# %% [markdown]
# # Study Assistant Phase - 1

# %%
from dotenv import load_dotenv
import os
import sys
from google import genai
from google.genai import types
from pydantic import BaseModel
import json
from pathlib import Path

# %% [markdown]
# ### Connecting Gemini API

# %%
load_dotenv()

api_key_gemini = os.getenv("GEMINI_API_KEY")

print(api_key_gemini[:10])
# Out:
# AQ.Ab8RN6K

# %%
print(Path.cwd())

root = Path.cwd().parents[1]
print(root)
# Out:
# C:\Users\DHANANJAY\Coding_Creations\Workshop\week_01\day_02
# C:\Users\DHANANJAY\Coding_Creations\Workshop

# %% [markdown]
# ### Create system prompt file
#
# In the directory root/prompts/study_assistant.py <br>
